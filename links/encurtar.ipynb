# %% [markdown]
# # Processo para encurtar URLS

# %%
from list_urls import find_urls

# %%
CAP = 17

adoc_path = f'../vol3/cap{CAP}.adoc'

with open(adoc_path) as adoc:
    lines = adoc.readlines()

urls = find_urls(lines, fpy=False)

htaccess_path = 'FPY.LI.htaccess'

from shortener import main
redirects = main(htaccess_path, urls)
# Out:
# 0 directives appended to FPY.LI.htaccess

# %%
for line in redirects:
    print(line)

# %%
import io

from replace_urls import main

pairs_file = io.StringIO('\n'.join(redirects))
main(pairs_file, adoc_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 6
#       3 from replace_urls import main
#       5 pairs_file = io.StringIO('\n'.join(redirects))
# ----> 6 main(pairs_file, adoc_path)
#
# File ~/flupy/pythonfluente2e/links/replace_urls.py:13, in main(pairs_file, adoc_path)
#      10     assert pair[0].startswith('/'), f'no path: {line}'
#      11     pairs.append(pair)
# ---> 13 assert len(pairs) > 0, f'no pairs found in {pairs_path}'
#      15 with open(adoc_path) as fp:
#      16     adoc = fp.read()
#
# NameError: name 'pairs_path' is not defined

# %% [markdown]
# Regex sugerida pelo DeepSeek, que funcionou no VS code para achar URLs de domínios sem inicial "f":
#
# ```https://(?!f[^.]+\.)[^/]+```

# %%
# !rg --pcre2 'https://(?!f[^.]+\.)[^/]+' ../online/cap24.adoc
